# %% [markdown]
# <a href="https://colab.research.google.com/github/LeoMSgit/Gerador-de-QR-Code/blob/main/gerador_qr_code_customizavel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Instruções de Uso
#
# 1 - Execute a célula "Instalar Bibliotecas" para instalar as bibliotecas necessárias.
#
#
# 2 - Execute a célula "Insirir texto ou link", insira o texto ou link a ser transformado em QR Code e pressione ENTER.
#
# ![Screenshot_1.png](data:image/png;base64,...)
#
# 3 - Execute a célula "Definir nome do arquivo" e insira o nome desejado do arquivo PNG do seu QR Code.
#
# ![Screenshot_2.png](data:image/png;base64,...)
#
# 4 - Execute a célula "Executar Programa" para criar seu QR Code personalizado.
#
# 5 - Acesse o sub-menu lateral "Arquivos" para baixar seu arquivo.
#
# ![Screenshot_3.png](data:image/png;base64,...)

# %% [markdown]
# # Instalar Bibliotecas

# %%
# !pip install qrcode
# !pip install opencv-python
# !pip install pyzbar
# !pip install pillow

import qrcode
import cv2
from PIL import Image
import os
# Out:
# Requirement already satisfied: qrcode in /usr/local/lib/python3.10/dist-packages (8.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: pyzbar in /usr/local/lib/python3.10/dist-packages (0.1.9)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (10.4.0)

# %% [markdown]
# # Inserir texto ou link

# %%
dados = input("Digite o site ou texto para gerar o QR Code: ")
# Out:
# Digite o site ou texto para gerar o QR Code: Teste

# %% [markdown]
# # Definir nome do arquivo

# %%
nome_arquivo = input("Digite o nome do arquivo (ou deixe em branco para usar 'myqrcode.png'): ")
if not nome_arquivo:
    nome_arquivo = "myqrcode.png"
elif not nome_arquivo.lower().endswith(".png"):
    nome_arquivo += ".png"
# Out:
# Digite o nome do arquivo (ou deixe em branco para usar 'myqrcode.png'): Teste

# %% [markdown]
# # Executar programa

# %%
# Função para criar o QR Code
def criar_qrcode(dados, nome_arquivo="myqrcode.png"):
    qr = qrcode.QRCode(
        version=1,
        error_correction=qrcode.constants.ERROR_CORRECT_L,
        box_size=10,
        border=4,
    )
    qr.add_data(dados)
    qr.make(fit=True)
    img = qr.make_image(fill='black', back_color='white')
    img.save(nome_arquivo)
    print(f"QR Code salvo como {nome_arquivo}")

    # Exibir QR Code no notebook
    return Image.open(nome_arquivo)

# Função para ler QR Code a partir de uma imagem
def ler_qrcode(nome_arquivo):
    img = cv2.imread(nome_arquivo)
    qr_codes = decode(img)
    return [qr_code.data.decode('utf-8') for qr_code in qr_codes]

  # Criar o QR Code e exibir no notebook
imagem_qr = criar_qrcode(dados, nome_arquivo)

# Exibir a imagem gerada no notebook
imagem_qr.show()

# Função opcional para mostrar a leitura do QR Code gerado
def testar_leitura_qrcode(nome_arquivo):
    print("Lendo QR Code gerado...")
    resultado = ler_qrcode(nome_arquivo)
    if resultado:
        print(f"Dados lidos do QR Code: {resultado}")
    else:
        print("Nenhum QR Code encontrado.")
# Out:
# QR Code salvo como Teste.png
